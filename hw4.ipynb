# %% [markdown]
# ##Задание 1
# Случайная непрерывная величина A имеет равномерное распределение на промежутке (200, 800].
# Найдите ее среднее значение и дисперсию.

# %% [markdown]
# $M(X)=\frac{a+b}{2}=\frac{200+800}{2}=500$ \\
# $D(X)=\frac{(b-a)^2}{12}=\frac{(800-200)^2}{12}=30000$

# %% [markdown]
# ##Задание 2
# О случайной непрерывной равномерно распределенной величине B известно, что ее дисперсия равна 0.2.
# Можно ли найти правую границу величины B и ее среднее значение зная, что левая граница равна 0.5?
# Если да, найдите ее.

# %% [markdown]
# $D(X)=\frac{(b-a)^2}{12}$ \\
# $b=\sqrt{12\cdot D(X)}+a=\sqrt{12\cdot 0,2}+0,5=2,049$ \\
# $M(X)=\frac{a+b}{2}=\frac{0,5+2,049}{2}=1,275$

# %% [markdown]
# ##Залание 3
# Непрерывная случайная величина X распределена нормально и задана плотностью распределения
# f(x) = (1 / (4 * sqrt(2*pi))) * (exp(-(x+2)**2) / 32).
# Найдите:
# а). M(X)
# б). D(X)
# в). std(X) (среднее квадратичное отклонение)

# %% [markdown]
# $$f\left(x\right)=\frac{1}{\sigma\sqrt{2\pi}}e^{-\frac{\left(x-a\right)^{2}}{2\sigma^{2}}}$$
# $$f\left(x\right)=\frac{1}{4\sqrt{2\pi}}e^{-\frac{\left(x+2\right)^{2}}{32}}$$
#
# а). $M(X) = a = -2$ \\
# б). $D(X) = \sigma^{2} = 32/2 = 16$ \\
# в). $std(X) = \sigma = 4$

# %% [markdown]
# ##Задание 4
# Рост взрослого населения города X имеет нормальное распределение.
# Причем, средний рост равен 174 см, а среднее квадратичное отклонение равно 8 см.
# Какова вероятность того, что случайным образом выбранный взрослый человек имеет рост:
# а). больше 182 см
# б). больше 190 см
# в). от 166 см до 190 см
# г). от 166 см до 182 см
# д). от 158 см до 190 см
# е). не выше 150 см или не ниже 190 см
# ё). не выше 150 см или не ниже 198 см
# ж). ниже 166 см.

# %% [markdown]
# а). больше 182 см \\
# $Z = (182-174)/8 = 1$ \\
# $P(рост > 182) = P(X > 1)=P(X < -1)=0,1587$ (по таблице) \\
#
# б). больше 190 см \\
# $Z = (190-174)/8 = 2$ \\
# $P(рост > 190) = P(X > 2)=P(X < -2)=0,0228$ (по таблице) \\
#
# в). от 166 см до 190 см \\
# $Z1 = (166-174)/8 = -1$ \\
# $Z2 = (190-174)/8 = 2$ \\
# $P(166<рост < 190)=P(-1<X < 2) = 0,954-(0,954-0,68)/2=0,817$ (правило трёх сигм) \\
#
# г). от 166 см до 182 см \\
# $Z1 = (166-174)/8 = -1$ \\
# $Z2 = (182-174)/8 = 1$ \\
# $P(166<рост < 182)=P(-1<X < 1) = 0,68$ (правило трёх сигм) \\
#
# д). от 158 см до 190 см \\
# $Z1 = (158-174)/8 = -2$ \\
# $Z2 = (190-174)/8 = 2$ \\
# $P(158<рост < 190)=P(-2<X < 2) = 0,954$ (правило трёх сигм) \\
#
# е). не выше 150 см или не ниже 190 см \\
# $Z1 = (150-174)/8 = -3$ \\
# $Z2 = (190-174)/8 = 2$ \\
# $P = P(рост \leq 150)+P(рост \geq 190)= P(X \leq -3)+P(X \geq 2) = (1-0,9972)/2+(1-0,954)/2=0,0244$ (правило трёх сигм) \\
#
# ё). не выше 150 см или не ниже 198 см \\
# $Z1 = (150-174)/8 = -3$ \\
# $Z2 = (198-174)/8 = 3$ \\
# $P = P(рост \leq 150)+P(рост \geq 198)= P(X \leq -3)+P(X \geq 3) = 1-0,9972=0,0028$ (правило трёх сигм) \\
#
# ж). ниже 166 см \\
# $Z = (166-174)/8 = -1$ \\
# $P(рост < 166) = P(X < -1)=0,1587$  (по таблице)

# %% [markdown]
# ##Задание 5
# На сколько сигм (средних квадратичных отклонений) отклоняется рост человека, равный 190 см, от
# математического ожидания роста в популяции, в которой M(X) = 178 см и D(X) = 25 кв.см?

# %% [markdown]
# $\sigma=\sqrt{D(X)}=\sqrt{25}=5 \ см$ \\
# $Z = (190-178)/5 = 2,4$
